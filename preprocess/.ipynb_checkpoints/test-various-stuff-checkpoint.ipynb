# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import shutil
import tqdm

# %%
import skimage, os
from skimage.morphology import ball, disk, dilation,binary_dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing, binary_opening 
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border, mark_boundaries
from skimage import data
from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.misc
from glob import glob
from skimage.io import imread

# %%
covidx_dir = os.getcwd() + '/' 
covidx_img_dir= covidx_dir 

covidx_img_dir_cropped = covidx_dir + 'mask/'

if not os.path.exists(covidx_img_dir_cropped):
    os.makedirs(covidx_img_dir_cropped)
print(covidx_dir)
print(covidx_img_dir)
print(covidx_img_dir_cropped)
# Out:
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/

# %%
def seedfill(img):

  rows,cols = img.shape 

  img_floodfill = img.copy()
  mask = np.zeros((rows+2,cols+2), np.uint8)

  '''
  # Floodfill from point (0, 0)
  found  = False 
  for x in range(cols): 
    for y in range(rows):
      if img_floodfill[y,x] == 0:
        found = True 
        break  
    if found:
      break 

  #cv2.floodFill(img_floodfill, mask, (x,y), 255);
  ''' 
  

  cv2.floodFill(img_floodfill, mask, (0,0), 255);
  cv2.floodFill(img_floodfill, mask, (0,rows-1), 255);
  cv2.floodFill(img_floodfill, mask, (cols-1,0), 255);
  cv2.floodFill(img_floodfill, mask, (cols-1,rows-1), 255);

  return img_floodfill

# %%
def body_contour(binary_image):
    """Helper function to get body contour"""
    _, contours, hier = cv2.findContours(binary_image, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
    areas = [cv2.contourArea(cnt) for cnt in contours]
    body_idx = np.argmax(areas)
    return contours[body_idx]


def auto_body_crop(image, plot=False):
    """Roughly crop an image to the body region"""
    # Create initial binary image
    filt_image = cv2.GaussianBlur(image, (5, 5), 0)
    
    if plot == True:
        f, plots = plt.subplots(3, 1, figsize=(5, 40))        
        plots[0].axis('off')
        plots[0].imshow(filt_image, cmap=plt.cm.bone)     
    
    thresh = cv2.threshold(filt_image[filt_image > 0], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[0]
    #print(thresh) 
    
    #bin_image = np.uint8(filt_image > thresh)  
    bin_image2 = np.uint8(filt_image > 240)         
    
    
    if plot == True:
        plots[1].axis('off')
        plots[1].imshow(bin_image, cmap=plt.cm.bone)     
    
    
    erode_kernel = np.ones((7, 7), dtype=np.uint8)
    bin_image = cv2.erode(bin_image, erode_kernel)
    
    #print(np.unique(bin_image))
    if plot == True:
        plots[2].axis('off')
        plots[2].imshow(bin_image, cmap=plt.cm.bone)     
        
    # Find body contour
    body_cont = body_contour(bin_image).squeeze()
    
    '''
    #find the lung rectangle        
    binary2 = ((1-bin_image)*255).astype(np.uint8) 
    kernel = np.ones((5,5), np.uint8) 
    binary2 = cv2.dilate(binary2, kernel, iterations=2) 
    binary2 = cv2.erode(binary2, kernel, iterations=2) 
    binary2 = seedfill(binary2) 
    binary2 = cv2.bitwise_not(binary2)    
    if plot == True:
        plots[3].axis('off')
        plots[3].imshow(binary2, cmap=plt.cm.bone) 
    '''    
    
    #print(body_cont)

    # Get bbox
    xmin = body_cont[:, 0].min()
    xmax = body_cont[:, 0].max() + 1
    ymin = body_cont[:, 1].min()
    ymax = body_cont[:, 1].max() + 1
       
    return bin_image, (xmin, ymin, xmax, ymax)


def auto_segment(image, plot=False):
    """Roughly crop an image to the body region"""
    # Create initial binary image
    filt_image = cv2.GaussianBlur(image, (5, 5), 0)
    
    if plot == True:
        f, plots = plt.subplots(9, 1, figsize=(5, 40))        
        plots[0].axis('off')
        plots[0].imshow(filt_image, cmap=plt.cm.bone)     
        
    filt_image = filt_image.astype('int16').astype('float32')
    max1 = np.max(filt_image)
    min1 = np.min(filt_image)
    
    filt_image = ((filt_image-min1)/(max1-min1)*255).astype('uint8')
    print(np.max(filt_image),np.min(filt_image))
    
    thresh = cv2.threshold(filt_image[filt_image > 0], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[0]
    
    thresh = min(thresh*1.5,175) 
    print(thresh) 
    
    bin_image = np.uint8(filt_image > thresh)  
    #bin_image = np.uint8(filt_image > 150)
    
    if plot == True:
        plots[1].axis('off')
        plots[1].imshow(bin_image, cmap=plt.cm.bone)     
        
    erode_kernel = np.ones((7, 7), dtype=np.uint8)
    bin_image = cv2.erode(bin_image, erode_kernel)
    #print(np.unique(bin_image))
    if plot == True:
        plots[2].axis('off')
        plots[2].imshow(bin_image, cmap=plt.cm.bone)     
      
    # Find body contour
    body_cont = body_contour(bin_image).squeeze()
    
    #print(body_cont)

    # Get bbox
    xmin = body_cont[:, 0].min()
    xmax = body_cont[:, 0].max() + 1
    ymin = body_cont[:, 1].min()
    ymax = body_cont[:, 1].max() + 1
       
        
    bin_image_inv = (1 - bin_image)*255 
    bin_image_inv = seedfill(bin_image_inv)/255 
    cleared = clear_border(bin_image_inv)
    if plot == True:
        plots[3].axis('off')
        plots[3].imshow(cleared, cmap=plt.cm.bone)     
    
    label_image = label(cleared)
    if plot == True:
        plots[4].axis('off')
        plots[4].imshow(label_image, cmap=plt.cm.bone) 
        
    '''
    Step 4: Keep the labels with 2 largest areas.
    '''
    areas = [r.area for r in regionprops(label_image)]
    areas.sort()
    if len(areas) > 2:
        for region in regionprops(label_image):
            if region.area < areas[-2]:
                for coordinates in region.coords:                
                       label_image[coordinates[0], coordinates[1]] = 0

    binary = label_image > 0
    if plot == True:
        plots[5].axis('off')
        plots[5].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 5: Erosion operation with a disk of radius 2. This operation is 
    seperate the lung nodules attached to the blood vessels.
    '''
    selem = disk(7)
    binary = binary_erosion(binary, selem)
    if plot == True:
        plots[6].axis('off')
        plots[6].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 6: Closure operation with a disk of radius 10. This operation is 
    to keep nodules attached to the lung wall.
    '''
    selem = disk(10)
    binary = binary_closing(binary, selem)
    if plot == True:
        plots[7].axis('off')
        plots[7].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 7: Fill in the small holes inside the binary mask of lungs.
    '''

    binary1 = binary.copy() 

    edges = roberts(binary)
    binary = ndi.binary_fill_holes(edges)
    if plot == True:
        plots[8].axis('off')
        plots[8].imshow(binary, cmap=plt.cm.bone) 
    
    
    return binary, binary1, (xmin, ymin, xmax, ymax)

# %%
#subsets = ['test'] # ,'val','train']
subsets = ['val']

from tqdm import tqdm

debug = True 

#filerer window 
(xmin,ymin,xmax,ymax) = (120, 240, 370, 340)

for subset in subsets:     
    
    val_annot_file = "{}_ICCV_MAI_new.txt".format(subset) 
    #fp = open(val_annot_file,'w')
    
    cls = ['covid','non-covid'] 
        
    for c in cls: 
        cls_path = os.listdir("{}/{}/".format(subset,c))
        num_scans = len(cls_path) 
        
        pbar = tqdm(total=num_scans)
        
        
        for ind in range(num_scans):            
            
            pbar.update()
            
            
            s = "ct_scan_{}".format(ind)
            s_path = "{}/{}/{}".format(subset,c,s)
            #print(s_path)
            
            sfiles = os.listdir(s_path) 
            sfiles = [x for x in sfiles if not x.startswith('.')]
            sfiles.sort(key = lambda x: int(x.split('.')[0]))
            
            fout_dir  = covidx_img_dir_cropped+"{}/{}/{}".format(subset,c,s)                        
            if not os.path.exists(fout_dir):
                os.makedirs(fout_dir)


            count = 0 
                
            for f in sfiles:

                count += 1 
                if count <150:
                    continue 

                
                f_full = "{}/{}/{}/{}".format(subset,c,s,f)
                img = cv2.imread(f_full, cv2.IMREAD_UNCHANGED)
                mask1, mask, (xmin, ymin, xmax, ymax) = auto_segment(img, plot=False)

                img_mask = img.copy()
                
                get_high_vals = mask == 0        
                img_mask[get_high_vals] = 0
                                
                
                fout_full = covidx_img_dir_cropped + f_full                
                
                
                print(fout_full)
                
                if debug: 
                    fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4)
                    ax1.imshow(img,cmap='gray')
                    ax2.imshow(mask,cmap='gray')
                    ax3.imshow(mask1,cmap='gray')
                    ax4.imshow(img_mask,cmap='gray')               

                if not os.path.exists(fout_full):
                    cv2.imwrite(fout_full,mask*255)


                
                #fp.write("{} {} {} {} {} {} {:2f}\n".format(f_full,c,xmin,ymin,xmax,ymax,percent_dark ))   
                
                if count>200:
                    break 
            break 
                
        break 
                
    #fp.close()
# Out:
#   0%|          | 0/165 [00:00<?, ?it/s]
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/149.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/150.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/151.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/152.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/153.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/154.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/155.jpg
# 255 0
# 171.5
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/156.jpg
# 255 0
# 171.5
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/157.jpg
# 255 0
# 171.5
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/158.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/159.jpg
# 255 0
# 171.5
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/160.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/161.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/162.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/163.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/164.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/165.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/166.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/167.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/168.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/169.jpg
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/170.jpg
# /media/ubuntu/MyHDataStor1/anaconda2/envs/pytorch1.7/lib/python3.7/site-packages/ipykernel_launcher.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/171.jpg
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/172.jpg
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/173.jpg
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/174.jpg
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/175.jpg
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/176.jpg
# 255 0
# 175
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/177.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/178.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/179.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/180.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/181.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/182.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/183.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/184.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/185.jpg
# 255 0
# 175.0
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/186.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/187.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/188.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/189.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/190.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/191.jpg
# 255 0
# 171.5
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/192.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/193.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/194.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/195.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/196.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/197.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/198.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/199.jpg
# 255 0
# 173.25
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/val/covid/ct_scan_0/200.jpg

# %%
val_annot_file = "{}_ICCV_MAI.txt".format(subset) 
fp = open(val_annot_file,'r')
lines = fp.readlines() 
lines = [x.strip() for x in lines]
fp.close()

# %%
val_annot_file = "{}_ICCV_MAI_new.txt".format(subset) 
fp = open(val_annot_file,'w')
for l in lines:
    
    tmp = l.split(' ') 
    
    if 'non-covid' in tmp[0]:
        cls = 'non-covid'
    else:
        cls = 'covid'
    
    l_new = "{} {} {} {} {} {}\n".format(tmp[0],cls,tmp[2],tmp[3],tmp[4],tmp[5])
    fp.write(l_new) 
    
fp.close()

# %%
f_full = 'test/subset1/4b1fcb92-d7ca-4903-b82e-43b030b15c63/11.jpg' 
img = cv2.imread(f_full, cv2.IMREAD_UNCHANGED)
plt.imshow(img,cmap='gray')

# %%
histr1 = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histr1)

# %%
img = img.astype(np.int16)
max1 = np.max(img)
min1 = np.min(img)
img = ((img-min1)/(max1-min1)*255).astype(np.uint8)
plt.imshow(img,cmap='gray')

# %%
cv2.imwrite("test.jpg",img)
# Out:
# True

# %%
histr = cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histr)

# %%
print(histr)
# Out:
# [[58291.]
#  [ 2727.]
#  [ 1986.]
#  [ 1286.]
#  [  935.]
#  [  723.]
#  [  650.]
#  [  699.]
#  [  705.]
#  [  736.]
#  [  768.]
#  [  785.]
#  [  884.]
#  [  897.]
#  [  992.]
#  [  927.]
#  [ 1103.]
#  [ 1122.]
#  [ 1231.]
#  [ 1273.]
#  [ 1412.]
#  [ 1507.]
#  [ 1598.]
#  [ 1641.]
#  [ 1736.]
#  [ 1776.]
#  [ 1752.]
#  [ 1897.]
#  [ 1910.]
#  [ 1842.]
#  [ 1763.]
#  [ 1756.]
#  [ 1618.]
#  [ 1570.]
#  [ 1447.]
#  [ 1437.]
#  [ 1345.]
#  [ 1371.]
#  [ 1253.]
#  [ 1258.]
#  [ 1103.]
#  [ 1177.]
#  [ 1107.]
#  [  970.]
#  [  979.]
#  [  951.]
#  [  976.]
#  [  909.]
#  [  845.]
#  [  813.]
#  [  805.]
#  [  793.]
#  [  741.]
#  [  657.]
#  [  673.]
#  [  656.]
#  [  674.]
#  [  651.]
#  [  565.]
#  [  560.]
#  [  513.]
#  [  528.]
#  [  525.]
#  [  532.]
#  [  497.]
#  [  516.]
#  [  449.]
#  [  428.]
#  [  471.]
#  [  437.]
#  [  418.]
#  [  420.]
#  [  460.]
#  [  375.]
#  [  369.]
#  [  380.]
#  [  340.]
#  [  364.]
#  [  373.]
#  [  335.]
#  [  389.]
#  [  340.]
#  [  339.]
#  [  323.]
#  [  316.]
#  [  328.]
#  [  294.]
#  [  316.]
#  [  314.]
#  [  352.]
#  [  300.]
#  [  309.]
#  [  363.]
#  [  328.]
#  [  329.]
#  [  327.]
#  [  328.]
#  [  310.]
#  [  322.]
#  [  317.]
#  [  301.]
#  [  320.]
#  [  289.]
#  [  272.]
#  [  297.]
#  [  314.]
#  [  300.]
#  [  270.]
#  [  313.]
#  [  302.]
#  [  254.]
#  [  259.]
#  [  261.]
#  [  282.]
#  [  291.]
#  [  292.]
#  [  329.]
#  [  293.]
#  [  278.]
#  [  290.]
#  [  310.]
#  [  276.]
#  [  297.]
#  [  341.]
#  [  306.]
#  [  329.]
#  [  316.]
#  [  344.]
#  [  326.]
#  [  332.]
#  [  342.]
#  [  342.]
#  [  373.]
#  [  364.]
#  [  395.]
#  [  384.]
#  [  381.]
#  [  394.]
#  [  430.]
#  [  427.]
#  [  468.]
#  [  493.]
#  [  477.]
#  [  438.]
#  [  471.]
#  [  528.]
#  [  570.]
#  [  555.]
#  [  544.]
#  [  605.]
#  [  604.]
#  [  634.]
#  [  625.]
#  [  664.]
#  [  662.]
#  [  706.]
#  [  722.]
#  [  771.]
#  [  758.]
#  [  790.]
#  [  830.]
#  [  833.]
#  [  841.]
#  [  920.]
#  [  945.]
#  [  975.]
#  [ 1009.]
#  [ 1037.]
#  [ 1010.]
#  [ 1171.]
#  [ 1132.]
#  [ 1195.]
#  [ 1287.]
#  [ 1289.]
#  [ 1375.]
#  [ 1405.]
#  [ 1420.]
#  [ 1551.]
#  [ 1557.]
#  [ 1462.]
#  [ 1593.]
#  [ 1643.]
#  [ 1581.]
#  [ 1591.]
#  [ 1544.]
#  [ 1495.]
#  [ 1518.]
#  [ 1511.]
#  [ 1491.]
#  [ 1481.]
#  [ 1475.]
#  [ 1432.]
#  [ 1423.]
#  [ 1393.]
#  [ 1352.]
#  [ 1397.]
#  [ 1368.]
#  [ 1315.]
#  [ 1293.]
#  [ 1274.]
#  [ 1227.]
#  [ 1203.]
#  [ 1234.]
#  [ 1137.]
#  [ 1148.]
#  [ 1143.]
#  [ 1068.]
#  [ 1098.]
#  [ 1055.]
#  [ 1029.]
#  [  963.]
#  [  949.]
#  [  901.]
#  [  859.]
#  [  896.]
#  [  893.]
#  [  777.]
#  [  813.]
#  [  771.]
#  [  774.]
#  [  688.]
#  [  670.]
#  [  683.]
#  [  671.]
#  [  640.]
#  [  607.]
#  [  586.]
#  [  561.]
#  [  579.]
#  [  511.]
#  [  512.]
#  [  497.]
#  [  521.]
#  [  493.]
#  [  459.]
#  [  425.]
#  [  420.]
#  [  360.]
#  [  376.]
#  [  347.]
#  [  356.]
#  [  347.]
#  [  348.]
#  [  309.]
#  [  330.]
#  [  302.]
#  [  295.]
#  [  296.]
#  [  284.]
#  [  291.]
#  [  288.]
#  [  414.]
#  [  707.]
#  [ 1005.]
#  [ 1478.]
#  [ 4747.]]

# %%
f_full = /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/

                img = cv2.imread(f_full, cv2.IMREAD_UNCHANGED)
                mask, (xmin, ymin, xmax, ymax) = auto_body_crop(img,plot=False)
                #auto_segment(img,plot=True)
                
                img_crop = img[ymin:ymax,xmin:xmax] 
                mask_crop = mask[ymin:ymax,xmin:xmax] 
                
                img_crop_2 = img_crop.copy()
                #img_crop_2 = 255 - img_crop_2                
                mask_crop_ind = (mask_crop == 0) 
                img_crop_2[mask_crop_ind] = 0 
                img_crop_3 = seedfill(img_crop_2,255)
                
                rows,cols = img_crop_3.shape
                percent_dark = np.sum(img_crop_3 <10)/rows/cols 
                #print(percent_dark)
                if debug: 
                    fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(5,1,figsize=(5, 40))
                    ax1.imshow(img,cmap='gray')                    
                    ax2.imshow(img_crop,cmap='gray')
                    ax3.imshow(img_crop_2,cmap='gray')
                    ax4.imshow(img_crop_3,cmap='gray')               
                    ax5.imshow(mask_crop,cmap='gray')
