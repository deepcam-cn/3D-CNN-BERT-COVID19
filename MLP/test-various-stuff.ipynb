# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import shutil
import tqdm 
import pickle

# %%
import skimage, os
from skimage.morphology import ball, disk, dilation,binary_dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing, binary_opening 
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border, mark_boundaries
from skimage import data
from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.misc
from glob import glob
from skimage.io import imread

# %%
f_file = 'features_037_98.242188_91.176471_checkpoint.pth.tar_5_val/features_val_covid_ct_scan_0.pkl'
with open(f_file, 'rb') as pk_file:
    [features,num_sets,slices_to_process] = pickle.load(pk_file)

# %%
f_files = 'features_037_98.242188_91.176471_checkpoint.pth.tar_val/features_val_covid_ct_scan_0.pkl'
with open(f_files, 'rb') as pk_file:
    [features2,num_sets2,slices_to_process2] = pickle.load(pk_file)

# %%
print(num_sets,num_sets2)
# Out:
# [4, 4, 5] [4, 4, 5]

# %%
for key in slices_to_process:    
    for i in range(len(slices_to_process[key])):        
        if slices_to_process[key][i] != slices_to_process2[key][i]:
            print(key,i,slices_to_process[key][i],slices_to_process2[key][i])

# %%
print(features.shape,features2.shape)
# Out:
# (5, 512) (5, 512)

# %%
for j in range(512):
    print(features[0][j], features2[0][j])
# Out:
# -0.40619496 -0.4315784
# 0.24975243 -0.5700648
# -0.6444565 -0.17864908
# -0.016022194 0.034590214
# -0.20073494 -0.035853937
# 0.05136506 -0.08068513
# 0.56447893 -0.44533622
# -0.16287029 -0.4160911
# 0.026433539 -0.5237529
# 0.008220583 -0.34900337
# 0.7476325 0.1309595
# -0.34114462 -0.6325957
# 0.23508653 0.29369473
# -0.004442364 0.53867495
# 0.12319224 -0.033580236
# 0.09803483 0.76784194
# -0.25009933 0.095222116
# -0.4290452 0.31141663
# 0.16704147 -0.2391227
# 0.21357554 0.124105714
# 0.16982496 -0.20823
# 0.19326043 -0.15005517
# 0.021839393 -0.9211206
# 0.14633927 0.19089863
# 0.58988696 -0.57244724
# -0.5430562 0.014348865
# -0.09862849 -0.2619633
# -0.2883513 0.4848003
# 0.23606582 0.3580102
# 0.21798244 -0.027833313
# 0.43897492 0.08906413
# 0.4705103 -0.19006899
# -0.16260874 0.35152334
# 0.27865925 -0.24920079
# 0.16478539 0.18618469
# -0.080795184 -0.23900676
# 0.2581791 -0.64426684
# 0.090536736 -0.024406835
# -0.30054894 -0.60298777
# 0.3460989 -0.17963439
# ...
