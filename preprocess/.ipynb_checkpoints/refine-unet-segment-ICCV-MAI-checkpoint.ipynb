# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import shutil
import tqdm

# %%
import skimage, os
from skimage.morphology import ball, disk, dilation,binary_dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing, binary_opening 
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border, mark_boundaries
from skimage import data
from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.misc
from glob import glob
from skimage.io import imread

# %%
covidx_dir = '/media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/'
covidx_img_dir= covidx_dir 
covidx_mask_dir= covidx_dir + 'mask/' 
data_list_dir = '/media/ubuntu/MyHDataStor2/products/COVID-19/ICCV-MAI/3D-CNN-BERT/BERT/datasets/settings/covid/'

print(covidx_dir)
print(covidx_img_dir)
print(covidx_mask_dir)
print(data_list_dir)
# Out:
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/
# /media/ubuntu/MyHDataStor2/datasets/COVID-19/ICCV-MIA/mask/
# /media/ubuntu/MyHDataStor2/products/COVID-19/ICCV-MAI/3D-CNN-BERT/BERT/datasets/settings/covid/

# %%
def seedfill(img):

  rows,cols = img.shape 

  img_floodfill = img.copy()
  mask = np.zeros((rows+2,cols+2), np.uint8)

  '''
  # Floodfill from point (0, 0)
  found  = False 
  for x in range(cols): 
    for y in range(rows):
      if img_floodfill[y,x] == 0:
        found = True 
        break  
    if found:
      break 

  #cv2.floodFill(img_floodfill, mask, (x,y), 255);
  ''' 
  

  cv2.floodFill(img_floodfill, mask, (0,0), 255);
  cv2.floodFill(img_floodfill, mask, (0,rows-1), 255);
  cv2.floodFill(img_floodfill, mask, (cols-1,0), 255);
  cv2.floodFill(img_floodfill, mask, (cols-1,rows-1), 255);

  return img_floodfill

# %%
def body_contour(binary_image):
    """Helper function to get body contour"""
    _, contours, hier = cv2.findContours(binary_image, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
    areas = [cv2.contourArea(cnt) for cnt in contours]
    body_idx = np.argmax(areas)
    return contours[body_idx]


def auto_body_crop(image, plot=False):
    """Roughly crop an image to the body region"""
    # Create initial binary image
    filt_image = cv2.GaussianBlur(image, (5, 5), 0)
    
    if plot == True:
        f, plots = plt.subplots(3, 1, figsize=(5, 40))        
        plots[0].axis('off')
        plots[0].imshow(filt_image, cmap=plt.cm.bone)     
    
    
    thresh = cv2.threshold(filt_image[filt_image > 0], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[0]
    #print(thresh) 
    
    bin_image = np.uint8(filt_image > thresh)  
    #bin_image2 = np.uint8(filt_image > 240)         
    
    
    if plot == True:
        plots[1].axis('off')
        plots[1].imshow(bin_image, cmap=plt.cm.bone)     
    
    
    erode_kernel = np.ones((7, 7), dtype=np.uint8)
    bin_image = cv2.erode(bin_image, erode_kernel)
    
    #print(np.unique(bin_image))
    if plot == True:
        plots[2].axis('off')
        plots[2].imshow(bin_image, cmap=plt.cm.bone)     
        
    # Find body contour
    body_cont = body_contour(bin_image).squeeze()
    
    '''
    #find the lung rectangle        
    binary2 = ((1-bin_image)*255).astype(np.uint8) 
    kernel = np.ones((5,5), np.uint8) 
    binary2 = cv2.dilate(binary2, kernel, iterations=2) 
    binary2 = cv2.erode(binary2, kernel, iterations=2) 
    binary2 = seedfill(binary2) 
    binary2 = cv2.bitwise_not(binary2)    
    if plot == True:
        plots[3].axis('off')
        plots[3].imshow(binary2, cmap=plt.cm.bone) 
    '''    
    
    #print(body_cont)

    # Get bbox
    xmin = body_cont[:, 0].min()
    xmax = body_cont[:, 0].max() + 1
    ymin = body_cont[:, 1].min()
    ymax = body_cont[:, 1].max() + 1
       
    return bin_image, (xmin, ymin, xmax, ymax)


def auto_segment(image, plot=False):
    """Roughly crop an image to the body region"""
    # Create initial binary image
    filt_image = cv2.GaussianBlur(image, (5, 5), 0)
    
    if plot == True:
        f, plots = plt.subplots(9, 1, figsize=(5, 40))        
        plots[0].axis('off')
        plots[0].imshow(filt_image, cmap=plt.cm.bone)     
    
    
    thresh = cv2.threshold(filt_image[filt_image > 0], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[0]
    print(thresh) 
    
    bin_image = np.uint8(filt_image > thresh)  
    #bin_image2 = np.uint8(filt_image > 240)             
    
    if plot == True:
        plots[1].axis('off')
        plots[1].imshow(bin_image, cmap=plt.cm.bone)     
        
    erode_kernel = np.ones((7, 7), dtype=np.uint8)
    bin_image = cv2.erode(bin_image, erode_kernel)
    #print(np.unique(bin_image))
    if plot == True:
        plots[2].axis('off')
        plots[2].imshow(bin_image, cmap=plt.cm.bone)     
        
 
        
    # Find body contour
    body_cont = body_contour(bin_image).squeeze()
    
    #print(body_cont)

    # Get bbox
    xmin = body_cont[:, 0].min()
    xmax = body_cont[:, 0].max() + 1
    ymin = body_cont[:, 1].min()
    ymax = body_cont[:, 1].max() + 1
       
        
    bin_image_inv = (1 - bin_image)*255 
    bin_image_inv = seedfill(bin_image_inv)/255 
    cleared = clear_border(bin_image_inv)
    if plot == True:
        plots[3].axis('off')
        plots[3].imshow(cleared, cmap=plt.cm.bone)     
    
    label_image = label(cleared)
    if plot == True:
        plots[4].axis('off')
        plots[4].imshow(label_image, cmap=plt.cm.bone) 
        
    '''
    Step 4: Keep the labels with 2 largest areas.
    '''
    areas = [r.area for r in regionprops(label_image)]
    areas.sort()
    if len(areas) > 2:
        for region in regionprops(label_image):
            if region.area < areas[-2]:
                for coordinates in region.coords:                
                       label_image[coordinates[0], coordinates[1]] = 0

    binary = label_image > 0
    if plot == True:
        plots[5].axis('off')
        plots[5].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 5: Erosion operation with a disk of radius 2. This operation is 
    seperate the lung nodules attached to the blood vessels.
    '''
    selem = disk(7)
    binary = binary_erosion(binary, selem)
    if plot == True:
        plots[6].axis('off')
        plots[6].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 6: Closure operation with a disk of radius 10. This operation is 
    to keep nodules attached to the lung wall.
    '''
    selem = disk(10)
    binary = binary_closing(binary, selem)
    if plot == True:
        plots[7].axis('off')
        plots[7].imshow(binary, cmap=plt.cm.bone) 
    '''
    Step 7: Fill in the small holes inside the binary mask of lungs.
    '''

    binary1 = binary.copy() 

    edges = roberts(binary)
    binary = ndi.binary_fill_holes(edges)
    if plot == True:
        plots[8].axis('off')
        plots[8].imshow(binary, cmap=plt.cm.bone) 
    
    
    return binary, binary1, (xmin, ymin, xmax, ymax)

# %%
def refine_mask(m_full):
    
    mask2 = cv2.imread(m_full, cv2.IMREAD_UNCHANGED)
    mask2 = (mask2/255).astype(np.uint8) 
    
    selem = disk(10)
    mask2_2  = binary_closing(mask2, selem)                
    label_image = label(mask2_2)
    
    '''
    Step 4: Keep the labels with 2 largest areas.
    '''
    areas = [r.area for r in regionprops(label_image)]
    areas.sort()
    if len(areas) > 2:
        for region in regionprops(label_image):
            if region.area < areas[-2]:
                for coordinates in region.coords:                
                    label_image[coordinates[0], coordinates[1]] = 0
    mask2_3 = label_image > 0               
    
    edges = roberts(mask2_3) 
    mask2_4 = ndi.binary_fill_holes(edges)
                
    return mask2,mask2_4

# %%
#subsets = ['test'] # ,'val','train']
subsets = ['train']

from tqdm import tqdm

debug = False
split = 4 

for subset in subsets:     

    list_file = data_list_dir + '{}_rgb_split{}.txt'.format(subset,split) 
    lines = open(list_file,"r").readlines() 

    pbar = tqdm(total = len(lines))
    
    for l in lines:
        
        print(l)
        
        pbar.update()
        
        l_splits = l.split()  
                
        l_path = l_splits[0]        
        c = l_splits[1]
        first_slice = int(l_splits[2])
        last_slice = int(l_splits[3])

        count = 0 
        for f in range(first_slice,last_slice+1):
            
            count +=1 
            
            #if count>10:
            #    break 
            
            f_full = "{}/{}.jpg".format(l_path,f)             
            m_full = 'mask/' + f_full 
            m_full_new = m_full+'_refined.jpg'
            
            
            if not os.path.exists(m_full_new) :
                mask0,mask = refine_mask(m_full)                
                cv2.imwrite(m_full_new, (mask*255).astype(np.uint8) )

                if False: 
                    fig, (ax1,ax2) = plt.subplots(1,2)
                    ax1.imshow(mask0*255,cmap='gray')
                    ax2.imshow(mask*255,cmap='gray')
# Out:
#   0%|          | 0/1552 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 108/1552 [00:00<00:01, 1078.71it/s]
# train/covid/ct_scan_0 covid 64 246 0 72 512 394
#
# train/covid/ct_scan_1 covid 45 235 0 92 512 480
#
# train/covid/ct_scan_2 covid 11 41 0 116 512 479
#
# train/covid/ct_scan_3 covid 7 42 0 117 512 480
#
# train/covid/ct_scan_4 covid 62 320 0 85 512 490
#
# train/covid/ct_scan_5 covid 49 367 0 52 512 442
#
# train/covid/ct_scan_6 covid 7 49 6 149 473 425
#
# train/covid/ct_scan_7 covid 46 247 0 108 501 439
#
# train/covid/ct_scan_8 covid 69 289 0 58 512 450
#
# train/covid/ct_scan_9 covid 57 246 0 104 512 491
#
# train/covid/ct_scan_10 covid 11 54 0 142 512 469
#
# train/covid/ct_scan_11 covid 44 300 0 79 512 466
#
# train/covid/ct_scan_12 covid 49 299 0 80 512 476
#
# train/covid/ct_scan_13 covid 7 44 0 70 512 453
#
# train/covid/ct_scan_14 covid 6 43 0 93 512 488
#
# train/covid/ct_scan_15 covid 49 327 0 49 512 425
#
# train/covid/ct_scan_16 covid 8 39 0 98 512 451
#
# train/covid/ct_scan_17 covid 50 328 0 107 512 439
#
# train/covid/ct_scan_18 covid 42 277 0 100 512 447
#
# train/covid/ct_scan_19 covid 64 309 0 124 504 437
#
# train/covid/ct_scan_20 covid 9 44 0 86 512 490
#
# train/covid/ct_scan_21 covid 43 265 0 112 512 457
#
# train/covid/ct_scan_22 covid 10 43 0 75 512 456
#
# train/covid/ct_scan_23 covid 7 41 0 77 512 440
#
# train/covid/ct_scan_24 covid 10 51 0 119 496 437
#
# train/covid/ct_scan_25 covid 10 46 0 0 512 450
#
# train/covid/ct_scan_26 covid 51 265 0 32 512 512
#
# train/covid/ct_scan_27 covid 9 55 5 84 512 465
#
# train/covid/ct_scan_28 covid 44 233 0 69 512 466
#
# train/covid/ct_scan_29 covid 5 46 0 93 512 458
#
# train/covid/ct_scan_30 covid 59 295 0 87 477 435
#
# train/covid/ct_scan_31 covid 3 70 6 71 512 484
#
# train/covid/ct_scan_32 covid 42 166 10 179 512 432
#
# train/covid/ct_scan_33 covid 66 261 0 112 497 414
#
# train/covid/ct_scan_34 covid 7 39 0 159 512 455
#
# train/covid/ct_scan_35 covid 40 265 0 85 512 454
#
# train/covid/ct_scan_36 covid 8 42 0 115 512 464
#
# train/covid/ct_scan_37 covid 49 275 0 135 512 494
#
# train/covid/ct_scan_38 covid 52 370 0 96 512 470
#
# train/covid/ct_scan_39 covid 53 295 4 71 512 484
#
# train/covid/ct_scan_40 covid 66 246 0 78 512 471
#
# train/covid/ct_scan_41 covid 47 348 33 128 512 471
#
# train/covid/ct_scan_42 covid 6 45 9 80 512 421
#
# train/covid/ct_scan_43 covid 49 362 0 78 512 432
#
# train/covid/ct_scan_44 covid 46 250 14 95 496 419
#
# train/covid/ct_scan_45 covid 8 44 34 140 486 438
#
# train/covid/ct_scan_46 covid 63 316 0 101 512 465
#
# train/covid/ct_scan_47 covid 2 70 0 71 500 484
#
# train/covid/ct_scan_48 covid 7 49 0 104 512 444
#
# train/covid/ct_scan_49 covid 5 56 0 114 504 465
#
# train/covid/ct_scan_50 covid 28 230 0 107 512 477
#
# train/covid/ct_scan_51 covid 11 65 0 108 512 439
#
# train/covid/ct_scan_52 covid 9 39 0 119 512 421
#
# train/covid/ct_scan_53 covid 68 282 0 0 500 443
#
# train/covid/ct_scan_54 covid 24 68 17 104 508 439
#
# train/covid/ct_scan_55 covid 9 42 0 124 501 437
#
# train/covid/ct_scan_56 covid 37 278 26 77 452 415
#
# train/covid/ct_scan_57 covid 10 54 8 95 499 408
#
# train/covid/ct_scan_58 covid 7 35 0 80 512 512
#
# train/covid/ct_scan_59 covid 50 261 0 101 492 441
#
# train/covid/ct_scan_60 covid 6 36 0 92 512 465
#
# train/covid/ct_scan_61 covid 62 272 0 78 512 484
#
# train/covid/ct_scan_62 covid 9 35 0 112 497 414
#
# train/covid/ct_scan_63 covid 65 408 0 73 512 396
#
# train/covid/ct_scan_64 covid 0 0 0 135 512 512
#
# train/covid/ct_scan_65 covid 5 42 0 163 512 512
#
# train/covid/ct_scan_66 covid 10 41 0 129 512 451
#
# train/covid/ct_scan_67 covid 63 248 0 83 512 466
#
# train/covid/ct_scan_68 covid 9 42 0 86 512 458
#
# train/covid/ct_scan_69 covid 10 43 0 84 512 428
#
# train/covid/ct_scan_70 covid 8 42 0 71 495 448
#
# train/covid/ct_scan_71 covid 46 285 0 50 500 433
#
# train/covid/ct_scan_72 covid 10 46 0 115 512 465
#
# train/covid/ct_scan_73 covid 54 387 0 45 512 405
#
# train/covid/ct_scan_74 covid 6 34 0 97 512 461
#
# train/covid/ct_scan_75 covid 40 211 0 115 512 465
#
# train/covid/ct_scan_76 covid 0 269 0 0 512 448
#
# train/covid/ct_scan_77 covid 49 382 0 72 512 461
#
# train/covid/ct_scan_78 covid 52 306 0 93 512 495
#
# train/covid/ct_scan_79 covid 106 442 0 96 512 466
#
# train/covid/ct_scan_80 covid 70 267 0 47 512 493
#
# train/covid/ct_scan_81 covid 0 258 0 41 512 459
#
# train/covid/ct_scan_82 covid 0 123 48 94 457 414
#
# train/covid/ct_scan_83 covid 63 325 0 95 512 512
#
# train/covid/ct_scan_84 covid 45 252 0 21 512 471
#
# train/covid/ct_scan_85 covid 53 277 0 97 512 439
#
# train/covid/ct_scan_86 covid 64 287 0 39 512 403
#
# train/covid/ct_scan_87 covid 76 336 0 0 512 470
#
# train/covid/ct_scan_88 covid 8 47 23 147 491 426
#
# train/covid/ct_scan_89 covid 16 38 0 123 512 465
#
# train/covid/ct_scan_90 covid 53 387 0 45 512 405
#
# train/covid/ct_scan_91 covid 7 44 0 70 512 452
#
# train/covid/ct_scan_92 covid 9 46 0 101 512 435
#
# train/covid/ct_scan_93 covid 11 328 0 107 512 439
#
# train/covid/ct_scan_94 covid 6 44 0 67 512 453
#
# train/covid/ct_scan_95 covid 49 256 24 121 512 435
#
# train/covid/ct_scan_96 covid 7 41 0 72 512 455
#
# train/covid/ct_scan_97 covid 49 413 0 86 501 448
#
# train/covid/ct_scan_98 covid 53 291 0 106 512 418
#
# train/covid/ct_scan_99 covid 49 305 0 0 512 512
#
# train/covid/ct_scan_100 covid 7 50 0 79 512 432
#
# train/covid/ct_scan_101 covid 13 43 0 109 512 484
#
# train/covid/ct_scan_102 covid 38 349 28 96 499 437
#
# train/covid/ct_scan_103 covid 61 262 0 126 512 462
#
# train/covid/ct_scan_104 covid 4 38 0 63 512 484
#
# train/covid/ct_scan_105 covid 53 250 0 85 512 441
#
# train/covid/ct_scan_106 covid 50 250 0 146 512 512
#
# train/covid/ct_scan_107 covid 0 3 0 131 512 478
#
# train/covid/ct_scan_108 covid 52 286 39 140 508 424
#
# train/covid/ct_scan_109 covid 48 367 0 0 512 474
#
# train/covid/ct_scan_110 covid 30 304 0 161 512 512
#
# train/covid/ct_scan_111 covid 50 263 0 92 512 480
#
# train/covid/ct_scan_112 covid 15 36 10 143 484 432
#
# train/covid/ct_scan_113 covid 10 49 0 93 512 458
#
# train/covid/ct_scan_114 covid 59 292 0 5 512 445
#
# train/covid/ct_scan_115 covid 103 281 10 140 485 432
#
# train/covid/ct_scan_116 covid 56 286 0 95 512 451
#
# train/covid/ct_scan_117 covid 0 108 16 101 502 475
#
# train/covid/ct_scan_118 covid 63 223 0 49 512 512
#
# train/covid/ct_scan_119 covid 62 272 0 78 512 484
#
# train/covid/ct_scan_120 covid 35 257 0 110 512 473
#
# train/covid/ct_scan_121 covid 6 48 25 61 506 400
#
# train/covid/ct_scan_122 covid 50 300 0 56 512 422
#
# train/covid/ct_scan_123 covid 45 254 0 118 512 443
#
# train/covid/ct_scan_124 covid 7 41 17 96 512 456
#
# train/covid/ct_scan_125 covid 62 251 0 73 512 441
#
# train/covid/ct_scan_126 covid 45 226 0 72 496 424
#
# train/covid/ct_scan_127 covid 48 367 0 0 512 474
#
# train/covid/ct_scan_128 covid 8 42 0 115 512 465
#
# train/covid/ct_scan_129 covid 81 324 0 79 512 453
#
# train/covid/ct_scan_130 covid 43 250 0 96 512 461
#
# train/covid/ct_scan_131 covid 8 32 0 108 512 460
#
# train/covid/ct_scan_132 covid 7 45 0 151 512 473
#
# train/covid/ct_scan_133 covid 50 277 30 105 478 412
#
# train/covid/ct_scan_134 covid 5 46 0 93 512 458
#
# train/covid/ct_scan_135 covid 54 347 0 28 512 443
#
# train/covid/ct_scan_136 covid 10 42 19 120 512 451
#
# train/covid/ct_scan_137 covid 8 35 0 104 512 460
#
# train/covid/ct_scan_138 covid 13 49 15 133 492 423
#
# train/covid/ct_scan_139 covid 66 279 0 70 512 452
#
# train/covid/ct_scan_140 covid 0 30 0 0 512 447
#
# train/covid/ct_scan_141 covid 44 185 0 73 512 449
#
# train/covid/ct_scan_142 covid 7 41 0 65 512 497
#
# train/covid/ct_scan_143 covid 64 352 0 69 512 490
#
# train/covid/ct_scan_144 covid 7 41 0 57 512 421
#
# train/covid/ct_scan_145 covid 12 59 0 141 512 469
#
# train/covid/ct_scan_146 covid 6 44 0 67 512 452
#
# train/covid/ct_scan_147 covid 57 283 0 107 512 440
#
# train/covid/ct_scan_148 covid 60 294 0 99 512 443
#
# train/covid/ct_scan_149 covid 7 50 0 52 512 442
#
# train/covid/ct_scan_150 covid 40 269 0 80 512 469
#
# train/covid/ct_scan_151 covid 70 360 0 132 512 445
#
# train/covid/ct_scan_152 covid 37 256 18 95 512 445
#
# train/covid/ct_scan_153 covid 7 55 0 96 512 492
#
# train/covid/ct_scan_154 covid 47 381 0 59 512 501
#
# train/covid/ct_scan_155 covid 43 287 0 95 512 512
#
# train/covid/ct_scan_156 covid 7 50 0 79 512 432
#
# train/covid/ct_scan_157 covid 57 303 0 97 512 442
#
# train/covid/ct_scan_158 covid 6 42 0 162 512 512
#
# train/covid/ct_scan_159 covid 13 60 0 69 512 408
#
# train/covid/ct_scan_160 covid 7 33 0 121 512 477
#
# train/covid/ct_scan_161 covid 13 60 0 69 512 413
#
# train/covid/ct_scan_162 covid 47 354 0 104 512 444
#
# train/covid/ct_scan_163 covid 34 379 0 18 512 473
#
# train/covid/ct_scan_164 covid 9 46 0 100 512 435
#
# train/covid/ct_scan_165 covid 8 67 0 51 512 441
#
# train/covid/ct_scan_166 covid 39 258 0 105 512 454
#
# train/covid/ct_scan_167 covid 51 276 0 78 512 494
#
# train/covid/ct_scan_168 covid 47 317 0 98 512 463
#
# train/covid/ct_scan_169 covid 51 264 0 92 512 480
#
# train/covid/ct_scan_170 covid 55 296 0 71 512 476
#
# train/covid/ct_scan_171 covid 45 405 0 89 512 482
#
# train/covid/ct_scan_172 covid 54 273 0 85 512 467
#
# train/covid/ct_scan_173 covid 67 320 0 93 512 440
#
# train/covid/ct_scan_174 covid 36 354 0 31 512 416
#
# train/covid/ct_scan_175 covid 39 192 0 76 512 426
#
# train/covid/ct_scan_176 covid 51 269 0 112 512 479
#
# train/covid/ct_scan_177 covid 56 390 0 101 512 482
#
# train/covid/ct_scan_178 covid 11 41 0 116 512 478
#
# train/covid/ct_scan_179 covid 36 267 0 40 512 441
#
# train/covid/ct_scan_180 covid 61 314 0 72 512 451
#
# train/covid/ct_scan_181 covid 45 259 0 93 512 506
#
# train/covid/ct_scan_182 covid 60 294 0 99 512 443
#
# train/covid/ct_scan_183 covid 0 137 30 93 485 447
#
# train/covid/ct_scan_184 covid 50 381 0 59 512 501
#
# train/covid/ct_scan_185 covid 25 212 0 161 512 512
#
# train/covid/ct_scan_186 covid 36 245 0 112 512 465
#
# train/covid/ct_scan_187 covid 80 263 0 80 512 500
#
# train/covid/ct_scan_188 covid 41 214 0 60 512 443
#
# train/covid/ct_scan_189 covid 5 38 0 5 512 430
#
# train/covid/ct_scan_190 covid 9 45 0 91 507 458
#
# train/covid/ct_scan_191 covid 36 246 0 47 512 478
#
# train/covid/ct_scan_192 covid 48 339 0 94 501 448
#
# train/covid/ct_scan_193 covid 38 301 0 88 512 479
#
# train/covid/ct_scan_194 covid 42 252 0 154 512 462
#
# train/covid/ct_scan_195 covid 65 250 0 42 512 477
#
# train/covid/ct_scan_196 covid 49 343 0 162 512 489
#
# train/covid/ct_scan_197 covid 54 229 0 101 497 420
#
# train/covid/ct_scan_198 covid 146 495 10 76 473 384
#
# train/covid/ct_scan_199 covid 38 301 0 88 512 478
#
# train/covid/ct_scan_200 covid 62 271 0 78 512 484
#
# train/covid/ct_scan_201 covid 57 258 0 104 512 461
#  13%|█▎        | 203/1552 [00:08<00:37, 35.95it/s]
# train/covid/ct_scan_202 covid 13 38 0 123 512 464
#
# train/covid/ct_scan_203 covid 38 336 0 92 512 458
#  13%|█▎        | 204/1552 [00:26<00:37, 35.95it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 205/1552 [00:36<1:32:49,  4.13s/it]
# train/covid/ct_scan_204 covid 5 52 0 90 512 512
#  13%|█▎        | 206/1552 [00:40<1:32:41,  4.13s/it]
# train/covid/ct_scan_205 covid 45 254 0 118 512 443
#  13%|█▎        | 207/1552 [00:57<3:03:56,  8.21s/it]
# train/covid/ct_scan_206 covid 33 199 0 159 512 453
# train/covid/ct_scan_558 covid 53 285 28 150 512 427
#  36%|███▌      | 560/1552 [1:17:11<3:17:23, 11.94s/it]
# train/covid/ct_scan_559 covid 37 275 0 37 512 447
#  36%|███▌      | 561/1552 [1:17:31<3:56:47, 14.34s/it]
# train/covid/ct_scan_560 covid 30 88 0 39 512 385
#  36%|███▌      | 562/1552 [1:17:36<3:10:05, 11.52s/it]
# train/covid/ct_scan_561 covid 14 83 21 97 499 444
#  36%|███▋      | 563/1552 [1:17:42<2:41:52,  9.82s/it]
# train/covid/ct_scan_562 covid 11 83 0 134 512 401
#  36%|███▋      | 564/1552 [1:17:48<2:23:23,  8.71s/it]
# train/covid/ct_scan_563 covid 36 211 0 52 512 415
#  36%|███▋      | 565/1552 [1:18:03<2:52:31, 10.49s/it]
# train/covid/ct_scan_564 covid 15 81 8 101 497 439
#  36%|███▋      | 566/1552 [1:18:08<2:28:13,  9.02s/it]
# train/covid/ct_scan_565 covid 0 41 0 103 502 446
#  37%|███▋      | 567/1552 [1:18:12<2:00:56,  7.37s/it]
# train/covid/ct_scan_566 covid 54 227 0 65 512 390
# ...
#  91%|█████████ | 1410/1552 [4:03:07<19:27,  8.22s/it]
# train/non-covid/ct_scan_722 non-covid 9 50 0 89 512 440
#  91%|█████████ | 1411/1552 [4:03:10<16:02,  6.83s/it]
# train/non-covid/ct_scan_723 non-covid 5 25 0 124 508 423
#  91%|█████████ | 1412/1552 [4:03:12<12:23,  5.31s/it]
# train/non-covid/ct_scan_724 non-covid 28 88 0 64 508 456
#  91%|█████████ | 1413/1552 [4:03:17<12:15,  5.29s/it]
# train/non-covid/ct_scan_725 non-covid 16 94 30 81 503 414
#  91%|█████████ | 1414/1552 [4:03:24<13:07,  5.70s/it]
# train/non-covid/ct_scan_726 non-covid 44 215 0 69 512 389
#  91%|█████████ | 1415/1552 [4:03:39<19:18,  8.45s/it]
# train/non-covid/ct_scan_727 non-covid 38 242 0 93 477 399
#  91%|█████████ | 1416/1552 [4:03:57<25:39, 11.32s/it]
# train/non-covid/ct_scan_728 non-covid 10 75 0 36 502 416
#  91%|█████████▏| 1417/1552 [4:04:03<21:43,  9.66s/it]
# train/non-covid/ct_scan_729 non-covid 0 50 19 101 512 402
#  91%|█████████▏| 1418/1552 [4:04:07<17:58,  8.05s/it]
# train/non-covid/ct_scan_730 non-covid 11 243 0 205 760 603
#  91%|█████████▏| 1419/1552 [4:04:28<26:22, 11.90s/it]
# train/non-covid/ct_scan_731 non-covid 27 235 0 93 512 489
#  91%|█████████▏| 1420/1552 [4:04:46<30:03, 13.66s/it]
# train/non-covid/ct_scan_732 non-covid 15 83 5 76 505 419
#  92%|█████████▏| 1421/1552 [4:04:51<24:40, 11.30s/it]
# train/non-covid/ct_scan_733 non-covid 38 252 43 116 475 389
#  92%|█████████▏| 1422/1552 [4:05:10<29:08, 13.45s/it]
# train/non-covid/ct_scan_734 non-covid 44 241 0 163 768 719
#  92%|█████████▏| 1423/1552 [4:05:27<31:12, 14.52s/it]
# train/non-covid/ct_scan_735 non-covid 7 52 0 61 501 413
#  92%|█████████▏| 1424/1552 [4:05:31<24:09, 11.33s/it]
# train/non-covid/ct_scan_736 non-covid 22 211 0 102 491 409
#  92%|█████████▏| 1425/1552 [4:05:47<26:57, 12.73s/it]
# train/non-covid/ct_scan_737 non-covid 12 95 0 67 512 422
#  92%|█████████▏| 1426/1552 [4:05:54<23:09, 11.03s/it]
# train/non-covid/ct_scan_738 non-covid 45 233 0 107 482 434
#  92%|█████████▏| 1427/1552 [4:06:10<26:17, 12.62s/it]
# train/non-covid/ct_scan_739 non-covid 16 606 0 117 504 385
#  92%|█████████▏| 1428/1552 [4:07:01<49:42, 24.05s/it]
# train/non-covid/ct_scan_740 non-covid 38 256 0 76 477 435
#  92%|█████████▏| 1429/1552 [4:07:19<45:56, 22.41s/it]
# train/non-covid/ct_scan_741 non-covid 39 237 0 65 499 410
#  92%|█████████▏| 1430/1552 [4:07:36<42:10, 20.74s/it]
# train/non-covid/ct_scan_742 non-covid 51 254 0 80 512 406
#  92%|█████████▏| 1431/1552 [4:07:54<39:44, 19.71s/it]
# train/non-covid/ct_scan_743 non-covid 0 117 0 97 768 653
#  92%|█████████▏| 1432/1552 [4:08:04<33:42, 16.86s/it]
# train/non-covid/ct_scan_744 non-covid 8 53 0 106 512 497
#  92%|█████████▏| 1433/1552 [4:08:08<25:47, 13.01s/it]
# train/non-covid/ct_scan_745 non-covid 13 54 0 58 512 401
#  92%|█████████▏| 1434/1552 [4:08:11<20:02, 10.19s/it]
# train/non-covid/ct_scan_746 non-covid 12 144 6 141 502 387
#  92%|█████████▏| 1435/1552 [4:08:23<20:33, 10.54s/it]
# train/non-covid/ct_scan_747 non-covid 7 45 0 141 512 397
#  93%|█████████▎| 1436/1552 [4:08:26<16:13,  8.39s/it]
# train/non-covid/ct_scan_748 non-covid 27 197 0 153 768 690
#  93%|█████████▎| 1437/1552 [4:08:41<19:31, 10.18s/it]
# train/non-covid/ct_scan_749 non-covid 12 71 0 53 512 444
#  93%|█████████▎| 1438/1552 [4:08:46<16:25,  8.65s/it]
# train/non-covid/ct_scan_750 non-covid 13 71 0 94 508 478
#  93%|█████████▎| 1439/1552 [4:08:51<14:11,  7.53s/it]
# train/non-covid/ct_scan_751 non-covid 12 80 0 82 512 459
#  93%|█████████▎| 1440/1552 [4:08:56<13:05,  7.02s/it]
# train/non-covid/ct_scan_752 non-covid 17 57 0 23 512 434
#  93%|█████████▎| 1441/1552 [4:09:00<10:59,  5.94s/it]
# train/non-covid/ct_scan_753 non-covid 42 241 34 75 512 438
#  93%|█████████▎| 1442/1552 [4:09:17<16:59,  9.26s/it]
# train/non-covid/ct_scan_754 non-covid 25 101 0 58 487 413
#  93%|█████████▎| 1443/1552 [4:09:23<15:19,  8.43s/it]
# train/non-covid/ct_scan_755 non-covid 56 273 0 10 512 420
#  93%|█████████▎| 1444/1552 [4:09:42<20:47, 11.55s/it]
# train/non-covid/ct_scan_756 non-covid 12 62 0 59 512 369
#  93%|█████████▎| 1445/1552 [4:09:46<16:43,  9.38s/it]
# train/non-covid/ct_scan_757 non-covid 17 83 0 101 512 404
#  93%|█████████▎| 1446/1552 [4:09:52<14:39,  8.30s/it]
# train/non-covid/ct_scan_758 non-covid 14 264 0 97 512 387
#  93%|█████████▎| 1447/1552 [4:10:14<21:22, 12.21s/it]
# train/non-covid/ct_scan_759 non-covid 12 76 0 57 512 452
#  93%|█████████▎| 1448/1552 [4:10:19<17:40, 10.20s/it]
# train/non-covid/ct_scan_760 non-covid 56 337 14 123 512 426
#  93%|█████████▎| 1449/1552 [4:10:43<24:34, 14.32s/it]
# train/non-covid/ct_scan_761 non-covid 8 63 0 120 505 446
#  93%|█████████▎| 1450/1552 [4:10:48<19:33, 11.50s/it]
# train/non-covid/ct_scan_762 non-covid 13 97 0 86 512 440
#  93%|█████████▎| 1451/1552 [4:10:55<17:11, 10.21s/it]
# train/non-covid/ct_scan_763 non-covid 13 69 0 84 501 434
#  94%|█████████▎| 1452/1552 [4:11:00<14:18,  8.59s/it]
# train/non-covid/ct_scan_764 non-covid 5 21 0 58 512 416
#  94%|█████████▎| 1453/1552 [4:11:01<10:37,  6.44s/it]
# train/non-covid/ct_scan_765 non-covid 45 264 18 38 512 413
#  94%|█████████▎| 1454/1552 [4:11:20<16:26, 10.07s/it]
# train/non-covid/ct_scan_766 non-covid 13 94 0 61 507 453
#  94%|█████████▍| 1455/1552 [4:11:27<14:48,  9.16s/it]
# train/non-covid/ct_scan_767 non-covid 0 150 0 186 768 696
#  94%|█████████▍| 1456/1552 [4:11:40<16:26, 10.27s/it]
# train/non-covid/ct_scan_768 non-covid 33 212 23 107 486 426
#  94%|█████████▍| 1457/1552 [4:11:55<18:31, 11.70s/it]
# train/non-covid/ct_scan_769 non-covid 35 287 0 57 512 446
#  94%|█████████▍| 1458/1552 [4:12:16<22:52, 14.60s/it]
# train/non-covid/ct_scan_770 non-covid 11 56 6 68 512 439
#  94%|█████████▍| 1459/1552 [4:12:20<17:39, 11.39s/it]
# train/non-covid/ct_scan_771 non-covid 38 255 23 146 484 422
#  94%|█████████▍| 1460/1552 [4:12:38<20:38, 13.46s/it]
# train/non-covid/ct_scan_772 non-covid 8 81 5 25 512 395
#  94%|█████████▍| 1461/1552 [4:12:45<17:06, 11.28s/it]
# train/non-covid/ct_scan_773 non-covid 15 47 0 75 512 418
#  94%|█████████▍| 1462/1552 [4:12:47<13:05,  8.73s/it]
# train/non-covid/ct_scan_774 non-covid 17 79 0 99 512 331
#  94%|█████████▍| 1463/1552 [4:12:53<11:25,  7.71s/it]
# train/non-covid/ct_scan_775 non-covid 57 341 42 74 512 417
#  94%|█████████▍| 1464/1552 [4:13:17<18:30, 12.62s/it]
# train/non-covid/ct_scan_776 non-covid 48 263 0 47 512 439
#  94%|█████████▍| 1465/1552 [4:13:35<20:41, 14.27s/it]
# train/non-covid/ct_scan_777 non-covid 24 237 0 37 512 414
#  94%|█████████▍| 1466/1552 [4:13:53<22:04, 15.40s/it]
# train/non-covid/ct_scan_778 non-covid 11 62 0 122 508 476
#  95%|█████████▍| 1467/1552 [4:13:57<17:09, 12.11s/it]
# train/non-covid/ct_scan_779 non-covid 35 227 7 94 489 417
#  95%|█████████▍| 1468/1552 [4:14:14<18:46, 13.41s/it]
# train/non-covid/ct_scan_780 non-covid 10 35 54 126 413 347
#  95%|█████████▍| 1469/1552 [4:14:16<13:56, 10.08s/it]
# train/non-covid/ct_scan_781 non-covid 15 106 85 75 430 437
#  95%|█████████▍| 1470/1552 [4:14:25<13:07,  9.60s/it]
# train/non-covid/ct_scan_782 non-covid 104 257 47 133 723 710
#  95%|█████████▍| 1471/1552 [4:14:38<14:29, 10.74s/it]
# train/non-covid/ct_scan_783 non-covid 13 58 0 75 505 390
#  95%|█████████▍| 1472/1552 [4:14:42<11:34,  8.68s/it]
# train/non-covid/ct_scan_784 non-covid 10 61 0 117 503 407
#  95%|█████████▍| 1473/1552 [4:14:46<09:43,  7.39s/it]
# train/non-covid/ct_scan_785 non-covid 13 85 0 61 512 437
#  95%|█████████▍| 1474/1552 [4:14:52<09:08,  7.03s/it]
# train/non-covid/ct_scan_786 non-covid 49 165 0 126 512 474
#  95%|█████████▌| 1475/1552 [4:15:02<10:11,  7.94s/it]
# train/non-covid/ct_scan_787 non-covid 52 301 0 80 512 367
#  95%|█████████▌| 1476/1552 [4:15:24<15:01, 11.87s/it]
# train/non-covid/ct_scan_788 non-covid 43 234 9 86 490 414
#  95%|█████████▌| 1477/1552 [4:15:40<16:28, 13.18s/it]
# train/non-covid/ct_scan_789 non-covid 14 99 30 112 448 392
#  95%|█████████▌| 1478/1552 [4:15:47<14:05, 11.43s/it]
# train/non-covid/ct_scan_790 non-covid 55 238 8 62 504 402
#  95%|█████████▌| 1479/1552 [4:16:03<15:23, 12.66s/it]
# train/non-covid/ct_scan_791 non-covid 56 226 40 72 461 391
#  95%|█████████▌| 1480/1552 [4:16:17<15:49, 13.18s/it]
# train/non-covid/ct_scan_792 non-covid 5 22 0 90 512 452
#  95%|█████████▌| 1481/1552 [4:16:19<11:27,  9.69s/it]
# train/non-covid/ct_scan_793 non-covid 6 50 0 61 512 413
#  95%|█████████▌| 1482/1552 [4:16:22<09:14,  7.92s/it]
# train/non-covid/ct_scan_794 non-covid 37 177 0 75 512 407
#  96%|█████████▌| 1483/1552 [4:16:34<10:26,  9.09s/it]
# train/non-covid/ct_scan_795 non-covid 13 65 0 91 512 507
#  96%|█████████▌| 1484/1552 [4:16:39<08:43,  7.70s/it]
# train/non-covid/ct_scan_796 non-covid 12 48 0 21 512 512
#  96%|█████████▌| 1485/1552 [4:16:42<07:07,  6.38s/it]
# train/non-covid/ct_scan_797 non-covid 14 63 30 114 488 418
#  96%|█████████▌| 1486/1552 [4:16:46<06:18,  5.73s/it]
# train/non-covid/ct_scan_798 non-covid 13 60 0 96 512 446
#  96%|█████████▌| 1487/1552 [4:16:50<05:41,  5.26s/it]
# train/non-covid/ct_scan_799 non-covid 9 56 0 72 512 512
#  96%|█████████▌| 1488/1552 [4:16:58<06:18,  5.91s/it]
# train/non-covid/ct_scan_800 non-covid 12 57 0 32 512 431
#  96%|█████████▌| 1489/1552 [4:17:02<05:34,  5.30s/it]
# train/non-covid/ct_scan_801 non-covid 12 62 0 46 512 387
#  96%|█████████▌| 1490/1552 [4:17:06<05:11,  5.02s/it]
# train/non-covid/ct_scan_802 non-covid 62 277 20 96 512 383
#  96%|█████████▌| 1491/1552 [4:17:24<09:11,  9.05s/it]
# train/non-covid/ct_scan_803 non-covid 11 58 0 43 512 466
#  96%|█████████▌| 1492/1552 [4:17:28<07:32,  7.54s/it]
# train/non-covid/ct_scan_804 non-covid 7 37 0 69 494 420
#  96%|█████████▌| 1493/1552 [4:17:31<05:57,  6.06s/it]
# train/non-covid/ct_scan_805 non-covid 47 295 0 62 482 425
#  96%|█████████▋| 1494/1552 [4:17:52<10:08, 10.49s/it]
# train/non-covid/ct_scan_806 non-covid 61 329 0 49 512 439
#  96%|█████████▋| 1495/1552 [4:18:14<13:22, 14.08s/it]
# train/non-covid/ct_scan_807 non-covid 47 245 0 132 768 621
#  96%|█████████▋| 1496/1552 [4:18:31<13:53, 14.88s/it]
# train/non-covid/ct_scan_808 non-covid 19 81 0 72 491 401
#  96%|█████████▋| 1497/1552 [4:18:36<10:59, 12.00s/it]
# train/non-covid/ct_scan_809 non-covid 6 73 0 118 512 419
#  97%|█████████▋| 1498/1552 [4:18:42<09:12, 10.22s/it]
# train/non-covid/ct_scan_810 non-covid 49 275 0 101 506 396
#  97%|█████████▋| 1499/1552 [4:19:01<11:20, 12.84s/it]
# train/non-covid/ct_scan_811 non-covid 16 78 5 100 512 440
#  97%|█████████▋| 1500/1552 [4:19:07<09:09, 10.57s/it]
# train/non-covid/ct_scan_812 non-covid 54 231 0 101 498 416
#  97%|█████████▋| 1501/1552 [4:19:22<10:09, 11.95s/it]
# train/non-covid/ct_scan_813 non-covid 37 171 0 60 512 366
#  97%|█████████▋| 1502/1552 [4:19:33<09:51, 11.84s/it]
# train/non-covid/ct_scan_814 non-covid 36 227 0 126 768 566
#  97%|█████████▋| 1503/1552 [4:19:50<10:44, 13.15s/it]
# train/non-covid/ct_scan_815 non-covid 0 347 0 49 512 459
#  97%|█████████▋| 1504/1552 [4:20:20<14:32, 18.19s/it]
# train/non-covid/ct_scan_816 non-covid 0 60 0 80 512 396
#  97%|█████████▋| 1505/1552 [4:20:25<11:11, 14.28s/it]
# train/non-covid/ct_scan_817 non-covid 11 88 0 76 512 454
#  97%|█████████▋| 1506/1552 [4:20:31<09:10, 11.96s/it]
# train/non-covid/ct_scan_818 non-covid 14 69 0 24 512 410
#  97%|█████████▋| 1507/1552 [4:20:36<07:19,  9.78s/it]
# train/non-covid/ct_scan_819 non-covid 3 249 0 113 512 391
#  97%|█████████▋| 1508/1552 [4:20:57<09:36, 13.10s/it]
# train/non-covid/ct_scan_820 non-covid 10 79 0 19 512 414
#  97%|█████████▋| 1509/1552 [4:21:03<07:50, 10.93s/it]
# train/non-covid/ct_scan_821 non-covid 7 59 0 66 512 462
#  97%|█████████▋| 1510/1552 [4:21:07<06:17,  9.00s/it]
# train/non-covid/ct_scan_822 non-covid 5 37 0 94 505 445
#  97%|█████████▋| 1511/1552 [4:21:10<04:52,  7.14s/it]
# train/non-covid/ct_scan_823 non-covid 36 104 48 69 512 340
#  97%|█████████▋| 1512/1552 [4:21:16<04:28,  6.72s/it]
# train/non-covid/ct_scan_824 non-covid 15 69 25 0 476 372
#  97%|█████████▋| 1513/1552 [4:21:21<04:00,  6.17s/it]
# train/non-covid/ct_scan_825 non-covid 11 54 15 36 512 400
#  98%|█████████▊| 1514/1552 [4:21:24<03:27,  5.46s/it]
# train/non-covid/ct_scan_826 non-covid 0 48 75 111 508 436
#  98%|█████████▊| 1515/1552 [4:21:29<03:08,  5.08s/it]
# train/non-covid/ct_scan_827 non-covid 20 74 20 80 489 391
#  98%|█████████▊| 1516/1552 [4:21:33<02:59,  4.99s/it]
# train/non-covid/ct_scan_828 non-covid 4 31 0 90 512 429
#  98%|█████████▊| 1517/1552 [4:21:36<02:26,  4.19s/it]
# train/non-covid/ct_scan_829 non-covid 0 204 0 85 512 477
#  98%|█████████▊| 1518/1552 [4:21:53<04:37,  8.17s/it]
# train/non-covid/ct_scan_830 non-covid 11 83 0 32 512 432
#  98%|█████████▊| 1519/1552 [4:21:59<04:11,  7.61s/it]
# train/non-covid/ct_scan_831 non-covid 41 204 0 80 512 406
#  98%|█████████▊| 1520/1552 [4:22:13<05:03,  9.47s/it]
# train/non-covid/ct_scan_832 non-covid 18 70 0 66 492 397
#  98%|█████████▊| 1521/1552 [4:22:18<04:07,  7.97s/it]
# train/non-covid/ct_scan_833 non-covid 45 185 0 51 512 392
#  98%|█████████▊| 1522/1552 [4:22:30<04:33,  9.13s/it]
# train/non-covid/ct_scan_834 non-covid 30 75 44 61 493 395
#  98%|█████████▊| 1523/1552 [4:22:33<03:39,  7.55s/it]
# train/non-covid/ct_scan_835 non-covid 14 58 12 131 508 442
#  98%|█████████▊| 1524/1552 [4:22:37<02:59,  6.42s/it]
# train/non-covid/ct_scan_836 non-covid 14 61 0 4 512 415
#  98%|█████████▊| 1525/1552 [4:22:41<02:33,  5.70s/it]
# train/non-covid/ct_scan_837 non-covid 7 34 36 88 467 420
#  98%|█████████▊| 1526/1552 [4:22:44<02:02,  4.69s/it]
# train/non-covid/ct_scan_838 non-covid 36 229 0 52 512 409
#  98%|█████████▊| 1527/1552 [4:23:00<03:26,  8.27s/it]
# train/non-covid/ct_scan_839 non-covid 4 24 48 149 440 393
#  98%|█████████▊| 1528/1552 [4:23:02<02:31,  6.32s/it]
# train/non-covid/ct_scan_840 non-covid 16 78 0 37 512 433
#  99%|█████████▊| 1529/1552 [4:23:07<02:18,  6.03s/it]
# train/non-covid/ct_scan_841 non-covid 14 86 0 50 512 433
#  99%|█████████▊| 1530/1552 [4:23:13<02:13,  6.06s/it]
# train/non-covid/ct_scan_842 non-covid 8 88 0 53 508 451
#  99%|█████████▊| 1531/1552 [4:23:20<02:12,  6.29s/it]
# train/non-covid/ct_scan_843 non-covid 65 313 8 97 492 417
#  99%|█████████▊| 1532/1552 [4:23:41<03:33, 10.69s/it]
# train/non-covid/ct_scan_844 non-covid 18 86 0 62 512 400
#  99%|█████████▉| 1533/1552 [4:23:47<02:55,  9.22s/it]
# train/non-covid/ct_scan_845 non-covid 42 142 0 145 512 414
#  99%|█████████▉| 1534/1552 [4:23:56<02:42,  9.01s/it]
# train/non-covid/ct_scan_846 non-covid 13 86 4 87 512 418
#  99%|█████████▉| 1535/1552 [4:24:02<02:18,  8.16s/it]
# train/non-covid/ct_scan_847 non-covid 41 266 61 113 455 410
#  99%|█████████▉| 1536/1552 [4:24:21<03:02, 11.43s/it]
# train/non-covid/ct_scan_848 non-covid 14 80 23 90 497 411
#  99%|█████████▉| 1537/1552 [4:24:26<02:25,  9.70s/it]
# train/non-covid/ct_scan_849 non-covid 18 85 0 87 508 458
#  99%|█████████▉| 1538/1552 [4:24:32<01:58,  8.49s/it]
# train/non-covid/ct_scan_850 non-covid 16 82 29 96 475 406
#  99%|█████████▉| 1539/1552 [4:24:38<01:39,  7.63s/it]
# train/non-covid/ct_scan_851 non-covid 12 79 0 47 512 412
#  99%|█████████▉| 1540/1552 [4:24:43<01:24,  7.06s/it]
# train/non-covid/ct_scan_852 non-covid 9 59 0 48 512 482
#  99%|█████████▉| 1541/1552 [4:24:48<01:08,  6.23s/it]
# train/non-covid/ct_scan_853 non-covid 8 206 10 0 500 507
#  99%|█████████▉| 1542/1552 [4:25:05<01:35,  9.55s/it]
# train/non-covid/ct_scan_854 non-covid 23 284 31 120 458 423
#  99%|█████████▉| 1543/1552 [4:25:27<01:59, 13.32s/it]
# train/non-covid/ct_scan_855 non-covid 16 57 0 95 484 388
#  99%|█████████▉| 1544/1552 [4:25:31<01:23, 10.42s/it]
# train/non-covid/ct_scan_856 non-covid 32 269 76 46 440 402
# 100%|█████████▉| 1545/1552 [4:25:51<01:33, 13.29s/it]
# train/non-covid/ct_scan_857 non-covid 72 293 0 109 512 414
# 100%|█████████▉| 1546/1552 [4:26:09<01:29, 14.91s/it]
# train/non-covid/ct_scan_858 non-covid 41 202 0 42 512 441
# 100%|█████████▉| 1547/1552 [4:26:23<01:12, 14.56s/it]
# train/non-covid/ct_scan_859 non-covid 72 279 14 95 462 395
# 100%|█████████▉| 1548/1552 [4:26:41<01:02, 15.52s/it]
# train/non-covid/ct_scan_860 non-covid 12 73 0 58 512 403
# 100%|█████████▉| 1549/1552 [4:26:47<00:37, 12.52s/it]
# train/non-covid/ct_scan_861 non-covid 0 182 0 46 512 426
# 100%|█████████▉| 1550/1552 [4:27:02<00:26, 13.41s/it]
# train/non-covid/ct_scan_862 non-covid 43 235 0 81 512 368
# 100%|█████████▉| 1551/1552 [4:27:18<00:14, 14.24s/it]
# train/non-covid/ct_scan_863 non-covid 0 148 0 93 512 450
# 100%|██████████| 1552/1552 [4:27:31<00:00, 13.71s/it]
# train/non-covid/ct_scan_864 non-covid 15 57 0 7 512 408

# %%
    
    
    val_annot_file = "{}_ICCV_MAI_new.txt".format(subset) 
    fp = open(val_annot_file,'w')
    
    cls = ['covid','non-covid'] 

    
    for c in cls: 
        cls_path = os.listdir("{}/{}/".format(subset,c))
        num_scans = len(cls_path) 
        
        pbar = tqdm(total=num_scans)
        
        for ind in range(num_scans):   
            
            #if ind>0:
            #    break 
            
            pbar.update()
            
            s = "ct_scan_{}".format(ind)
            s_path = "{}/{}/{}".format(subset,c,s)
            #print(s_path)
            
            sfiles = os.listdir(s_path) 
            sfiles = [x for x in sfiles if not x.startswith('.')]
            sfiles.sort(key = lambda x: int(x.split('.')[0]))
            
            if save_cropped_image: 
                fout_dir  = "cropped/{}/{}/{}".format(subset,c,s)            
                if not os.path.exists(fout_dir):
                    os.makedirs(fout_dir)
                    
            count = 0         
            
            for f in sfiles:
                count += 1 
                
                #if count<100 or count>150:
                #    continue 
                
                f_full = "{}/{}/{}/{}".format(subset,c,s,f)
                
                #print(f_full)
                
                img = cv2.imread(f_full, cv2.IMREAD_UNCHANGED)
                mask, (xmin, ymin, xmax, ymax) = auto_body_crop(img,plot=False)
                
                '''
                img_2 = img.copy()
                #img_crop_2 = 255 - img_crop_2                
                mask_ind = (mask == 0) 
                img_2[mask_ind] = 0                 
                #img_2 = seedfill(img_2)
                '''
                
                m_full = 'mask/' + f_full                 
                #print(m_full) 
                
                mask2 = cv2.imread(m_full, cv2.IMREAD_UNCHANGED)
                mask2 = (mask2/255).astype(np.uint8) 
                
                #print(np.unique(mask2))
                
                selem = disk(20)
                mask2_2  = binary_closing(mask2, selem)                
                label_image = label(mask2_2)
                
                '''
                Step 4: Keep the labels with 2 largest areas.
        
                '''
                areas = [r.area for r in regionprops(label_image)]
                areas.sort()
                if len(areas) > 2:
                    for region in regionprops(label_image):
                        if region.area < areas[-2]:
                            for coordinates in region.coords:                
                                label_image[coordinates[0], coordinates[1]] = 0

                mask2_3 = label_image > 0               
                edges = roberts(mask2_3) 
                mask2_3 = ndi.binary_fill_holes(mask2_3)
                
                
                img_3 = img.copy()
                #img_crop_2 = 255 - img_crop_2                
                mask_ind = (mask2_3 == 0) 
                img_3[mask_ind] = 0                 
                #img_3 = seedfill(img_3)
                
                
                if debug: 
                    fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(1,5)
                    ax1.imshow(img,cmap='gray')
                    ax2.imshow(mask2,cmap='gray')
                    ax3.imshow(mask2_2,cmap='gray')
                    ax4.imshow(mask2_3,cmap='gray')
                    ax5.imshow(img_3,cmap='gray')

                
                if save_cropped_image: 
                    fout_full = 'cropped/' + f_full 
                    #print(fout_full)
                    if not os.path.exists(fout_full):
                        cv2.imwrite(fout_full,img_crop)


                m2_full = m_full + '_refined.jpg' 
                cv2.imwrite(m2_full, mask2_3*255)
                
                #m2_full = m_full + '_refined_image.jpg' 
                #cv2.imwrite(m2_full, img_3)
                
                        
                fp.write("{} {} {} {} {} {} {:2f}\n".format(f_full,c,xmin,ymin,xmax,ymax,percent_dark ))        
    fp.close()
